# %%
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\AADITYA
# [nltk_data]     PORWAL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\AADITYA
# [nltk_data]     PORWAL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
x="Hello, how are you?"
from nltk.tokenize import word_tokenize
w= word_tokenize(x)
print(w)
# Out:
# ['Hello', ',', 'how', 'are', 'you', '?']

# %%
import torch
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
# Out:
# NVIDIA GeForce RTX 3050 6GB Laptop GPU
# 12.1
# CUDA available: True

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\AADITYA PORWAL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
#Part of speech tagging
from nltk import pos_tag, word_tokenize
x="Hello, how are you?"
w= word_tokenize(x)
p= pos_tag(w)
print (p)
# Out:
# [('Hello', 'NNP'), (',', ','), ('how', 'WRB'), ('are', 'VBP'), ('you', 'PRP'), ('?', '.')]
